# %% [markdown]
# ### Create training data for CBOW:
# - For each word in your corpus, create a 5-item context window
# - The input will be the context words, and the target will be the center word
# - We'll need to convert these words into word IDs from your tokenizer
#
# ### Build the CBOW architecture:
# - Input layer (context words)
# - Hidden layer (embedding dimension)
# - Output layer (prediction of center word using softmax)

# %% [markdown]
# CREATE TRAINING DATA

# %%
import sys
sys.path.append('../scripts')

from tokenizer import tokenizer

# Load the wiki data
filename = "../data/wiki_text_data.txt"

text = open(filename, 'r', encoding='utf-8').read().lower()


# First tokenize the wiki text
word_to_id, id_to_word, corpus = tokenizer(text)
print("Tokenisation complete")
# Out:
# Number of unique words included in word count before filtering:  253854
# Number of unique words included in word count after filtering:  71290
# Tokenisation complete

# %%
# Generate the training data from the corpus
# The training data looks like a list of tuples, 
# where each tuple contains a list of context words and the target word (not the IDs)

def generate_training_data(corpus):
    data = []

    # start from index 2 and end 2 positions before the last word
    # this ensures we always have 2 words before and after the target word
    # for a 5-len sliding window

    for i in range(2, len(corpus) - 2):
        # Get the context words
        # 'i' is the index of the target word
        # [i-2:i] gets the two words before the target word
        # [i+1:i+3] gets the two words after the target word
        context_words = corpus[i-2:i] + corpus[i+1:i+3]
        
        # Get the target word
        target_word = corpus[i]

        # Append the tuple to the data list
        data.append((context_words, target_word))

    return data

# %%
# usage
training_data = generate_training_data(corpus)
print("CBOW training data generated")
# Out:
# CBOW training data generated

# %%
# check the function
training_data[:200]
# Out:
# [(['anarchism', 'originated', 'a', 'term'], 'as'),
#  (['originated', 'as', 'term', 'of'], 'a'),
#  (['as', 'a', 'of', 'abuse'], 'term'),
#  (['a', 'term', 'abuse', 'first'], 'of'),
#  (['term', 'of', 'first', 'used'], 'abuse'),
#  (['of', 'abuse', 'used', 'against'], 'first'),
#  (['abuse', 'first', 'against', 'early'], 'used'),
#  (['first', 'used', 'early', 'working'], 'against'),
#  (['used', 'against', 'working', 'class'], 'early'),
#  (['against', 'early', 'class', 'radicals'], 'working'),
#  (['early', 'working', 'radicals', 'including'], 'class'),
#  (['working', 'class', 'including', 'the'], 'radicals'),
#  (['class', 'radicals', 'the', 'diggers'], 'including'),
#  (['radicals', 'including', 'diggers', 'of'], 'the'),
#  (['including', 'the', 'of', 'the'], 'diggers'),
#  (['the', 'diggers', 'the', 'english'], 'of'),
#  (['diggers', 'of', 'english', 'revolution'], 'the'),
#  (['of', 'the', 'revolution', 'and'], 'english'),
#  (['the', 'english', 'and', 'the'], 'revolution'),
#  (['english', 'revolution', 'the', 'sans'], 'and'),
#  (['revolution', 'and', 'sans', 'culottes'], 'the'),
#  (['and', 'the', 'culottes', 'of'], 'sans'),
#  (['the', 'sans', 'of', 'the'], 'culottes'),
#  (['sans', 'culottes', 'the', 'french'], 'of'),
#  (['culottes', 'of', 'french', 'revolution'], 'the'),
#  (['of', 'the', 'revolution', 'whilst'], 'french'),
#  (['the', 'french', 'whilst', 'the'], 'revolution'),
#  (['french', 'revolution', 'the', 'term'], 'whilst'),
#  (['revolution', 'whilst', 'term', 'is'], 'the'),
#  (['whilst', 'the', 'is', 'still'], 'term'),
#  (['the', 'term', 'still', 'used'], 'is'),
#  (['term', 'is', 'used', 'in'], 'still'),
#  (['is', 'still', 'in', 'a'], 'used'),
#  (['still', 'used', 'a', 'pejorative'], 'in'),
#  (['used', 'in', 'pejorative', 'way'], 'a'),
#  (['in', 'a', 'way', 'to'], 'pejorative'),
#  (['a', 'pejorative', 'to', 'describe'], 'way'),
#  (['pejorative', 'way', 'describe', 'any'], 'to'),
#  (['way', 'to', 'any', 'act'], 'describe'),
#  (['to', 'describe', 'act', 'that'], 'any'),
#  (['describe', 'any', 'that', 'used'], 'act'),
#  (['any', 'act', 'used', 'violent'], 'that'),
#  (['act', 'that', 'violent', 'means'], 'used'),
#  (['that', 'used', 'means', 'to'], 'violent'),
#  (['used', 'violent', 'to', 'destroy'], 'means'),
#  (['violent', 'means', 'destroy', 'the'], 'to'),
#  (['means', 'to', 'the', 'organization'], 'destroy'),
#  (['to', 'destroy', 'organization', 'of'], 'the'),
#  (['destroy', 'the', 'of', 'society'], 'organization'),
#  (['the', 'organization', 'society', 'it'], 'of'),
#  (['organization', 'of', 'it', 'has'], 'society'),
#  (['of', 'society', 'has', 'also'], 'it'),
#  (['society', 'it', 'also', 'been'], 'has'),
#  (['it', 'has', 'been', 'taken'], 'also'),
#  (['has', 'also', 'taken', 'up'], 'been'),
#  (['also', 'been', 'up', 'as'], 'taken'),
#  (['been', 'taken', 'as', 'a'], 'up'),
#  (['taken', 'up', 'a', 'positive'], 'as'),
#  (['up', 'as', 'positive', 'label'], 'a'),
#  (['as', 'a', 'label', 'by'], 'positive'),
#  (['a', 'positive', 'by', 'self'], 'label'),
#  (['positive', 'label', 'self', 'defined'], 'by'),
#  (['label', 'by', 'defined', 'anarchists'], 'self'),
#  (['by', 'self', 'anarchists', 'the'], 'defined'),
#  (['self', 'defined', 'the', 'word'], 'anarchists'),
#  (['defined', 'anarchists', 'word', 'anarchism'], 'the'),
#  (['anarchists', 'the', 'anarchism', 'is'], 'word'),
#  (['the', 'word', 'is', 'derived'], 'anarchism'),
#  (['word', 'anarchism', 'derived', 'from'], 'is'),
#  (['anarchism', 'is', 'from', 'the'], 'derived'),
#  (['is', 'derived', 'the', 'greek'], 'from'),
#  (['derived', 'from', 'greek', 'without'], 'the'),
#  (['from', 'the', 'without', 'archons'], 'greek'),
#  (['the', 'greek', 'archons', 'ruler'], 'without'),
#  (['greek', 'without', 'ruler', 'chief'], 'archons'),
#  (['without', 'archons', 'chief', 'king'], 'ruler'),
#  (['archons', 'ruler', 'king', 'anarchism'], 'chief'),
#  (['ruler', 'chief', 'anarchism', 'as'], 'king'),
#  (['chief', 'king', 'as', 'a'], 'anarchism'),
#  (['king', 'anarchism', 'a', 'political'], 'as'),
#  (['anarchism', 'as', 'political', 'philosophy'], 'a'),
#  (['as', 'a', 'philosophy', 'is'], 'political'),
#  (['a', 'political', 'is', 'the'], 'philosophy'),
#  (['political', 'philosophy', 'the', 'belief'], 'is'),
#  (['philosophy', 'is', 'belief', 'that'], 'the'),
#  (['is', 'the', 'that', 'rulers'], 'belief'),
#  (['the', 'belief', 'rulers', 'are'], 'that'),
#  (['belief', 'that', 'are', 'unnecessary'], 'rulers'),
#  (['that', 'rulers', 'unnecessary', 'and'], 'are'),
#  (['rulers', 'are', 'and', 'should'], 'unnecessary'),
#  (['are', 'unnecessary', 'should', 'be'], 'and'),
#  (['unnecessary', 'and', 'be', 'abolished'], 'should'),
#  (['and', 'should', 'abolished', 'although'], 'be'),
#  (['should', 'be', 'although', 'there'], 'abolished'),
#  (['be', 'abolished', 'there', 'are'], 'although'),
#  (['abolished', 'although', 'are', 'differing'], 'there'),
#  (['although', 'there', 'differing', 'interpretations'], 'are'),
#  (['there', 'are', 'interpretations', 'of'], 'differing'),
#  (['are', 'differing', 'of', 'what'], 'interpretations'),
#  (['differing', 'interpretations', 'what', 'this'], 'of'),
#  (['interpretations', 'of', 'this', 'means'], 'what'),
#  (['of', 'what', 'means', 'anarchism'], 'this'),
#  (['what', 'this', 'anarchism', 'also'], 'means'),
#  (['this', 'means', 'also', 'refers'], 'anarchism'),
#  (['means', 'anarchism', 'refers', 'to'], 'also'),
#  (['anarchism', 'also', 'to', 'related'], 'refers'),
#  (['also', 'refers', 'related', 'social'], 'to'),
#  (['refers', 'to', 'social', 'movements'], 'related'),
#  (['to', 'related', 'movements', 'that'], 'social'),
#  (['related', 'social', 'that', 'advocate'], 'movements'),
#  (['social', 'movements', 'advocate', 'the'], 'that'),
#  (['movements', 'that', 'the', 'elimination'], 'advocate'),
#  (['that', 'advocate', 'elimination', 'of'], 'the'),
#  (['advocate', 'the', 'of', 'authoritarian'], 'elimination'),
#  (['the', 'elimination', 'authoritarian', 'institutions'], 'of'),
#  (['elimination', 'of', 'institutions', 'particularly'], 'authoritarian'),
#  (['of', 'authoritarian', 'particularly', 'the'], 'institutions'),
#  (['authoritarian', 'institutions', 'the', 'state'], 'particularly'),
#  (['institutions', 'particularly', 'state', 'the'], 'the'),
#  (['particularly', 'the', 'the', 'word'], 'state'),
#  (['the', 'state', 'word', 'anarchy'], 'the'),
#  (['state', 'the', 'anarchy', 'as'], 'word'),
#  (['the', 'word', 'as', 'most'], 'anarchy'),
#  (['word', 'anarchy', 'most', 'anarchists'], 'as'),
#  (['anarchy', 'as', 'anarchists', 'use'], 'most'),
#  (['as', 'most', 'use', 'it'], 'anarchists'),
#  (['most', 'anarchists', 'it', 'does'], 'use'),
#  (['anarchists', 'use', 'does', 'not'], 'it'),
#  (['use', 'it', 'not', 'imply'], 'does'),
#  (['it', 'does', 'imply', 'chaos'], 'not'),
#  (['does', 'not', 'chaos', 'nihilism'], 'imply'),
#  (['not', 'imply', 'nihilism', 'or'], 'chaos'),
#  (['imply', 'chaos', 'or', 'anomie'], 'nihilism'),
#  (['chaos', 'nihilism', 'anomie', 'but'], 'or'),
#  (['nihilism', 'or', 'but', 'rather'], 'anomie'),
#  (['or', 'anomie', 'rather', 'a'], 'but'),
#  (['anomie', 'but', 'a', 'harmonious'], 'rather'),
#  (['but', 'rather', 'harmonious', 'anti'], 'a'),
#  (['rather', 'a', 'anti', 'authoritarian'], 'harmonious'),
#  (['a', 'harmonious', 'authoritarian', 'society'], 'anti'),
#  (['harmonious', 'anti', 'society', 'in'], 'authoritarian'),
#  (['anti', 'authoritarian', 'in', 'place'], 'society'),
#  (['authoritarian', 'society', 'place', 'of'], 'in'),
#  (['society', 'in', 'of', 'what'], 'place'),
#  (['in', 'place', 'what', 'are'], 'of'),
#  (['place', 'of', 'are', 'regarded'], 'what'),
#  (['of', 'what', 'regarded', 'as'], 'are'),
#  (['what', 'are', 'as', 'authoritarian'], 'regarded'),
#  (['are', 'regarded', 'authoritarian', 'political'], 'as'),
#  (['regarded', 'as', 'political', 'structures'], 'authoritarian'),
#  (['as', 'authoritarian', 'structures', 'and'], 'political'),
#  (['authoritarian', 'political', 'and', 'coercive'], 'structures'),
#  (['political', 'structures', 'coercive', 'economic'], 'and'),
#  (['structures', 'and', 'economic', 'institutions'], 'coercive'),
#  (['and', 'coercive', 'institutions', 'anarchists'], 'economic'),
#  (['coercive', 'economic', 'anarchists', 'advocate'], 'institutions'),
#  (['economic', 'institutions', 'advocate', 'social'], 'anarchists'),
#  (['institutions', 'anarchists', 'social', 'relations'], 'advocate'),
#  (['anarchists', 'advocate', 'relations', 'based'], 'social'),
#  (['advocate', 'social', 'based', 'upon'], 'relations'),
#  (['social', 'relations', 'upon', 'voluntary'], 'based'),
#  (['relations', 'based', 'voluntary', 'association'], 'upon'),
#  (['based', 'upon', 'association', 'of'], 'voluntary'),
#  (['upon', 'voluntary', 'of', 'autonomous'], 'association'),
#  (['voluntary', 'association', 'autonomous', 'individuals'], 'of'),
#  (['association', 'of', 'individuals', 'mutual'], 'autonomous'),
#  (['of', 'autonomous', 'mutual', 'aid'], 'individuals'),
#  (['autonomous', 'individuals', 'aid', 'and'], 'mutual'),
#  (['individuals', 'mutual', 'and', 'self'], 'aid'),
#  (['mutual', 'aid', 'self', 'governance'], 'and'),
#  (['aid', 'and', 'governance', 'while'], 'self'),
#  (['and', 'self', 'while', 'anarchism'], 'governance'),
#  (['self', 'governance', 'anarchism', 'is'], 'while'),
#  (['governance', 'while', 'is', 'most'], 'anarchism'),
#  (['while', 'anarchism', 'most', 'easily'], 'is'),
#  (['anarchism', 'is', 'easily', 'defined'], 'most'),
#  (['is', 'most', 'defined', 'by'], 'easily'),
#  (['most', 'easily', 'by', 'what'], 'defined'),
#  (['easily', 'defined', 'what', 'it'], 'by'),
#  (['defined', 'by', 'it', 'is'], 'what'),
#  (['by', 'what', 'is', 'against'], 'it'),
#  (['what', 'it', 'against', 'anarchists'], 'is'),
#  (['it', 'is', 'anarchists', 'also'], 'against'),
#  (['is', 'against', 'also', 'offer'], 'anarchists'),
#  (['against', 'anarchists', 'offer', 'positive'], 'also'),
#  (['anarchists', 'also', 'positive', 'visions'], 'offer'),
#  (['also', 'offer', 'visions', 'of'], 'positive'),
#  (['offer', 'positive', 'of', 'what'], 'visions'),
#  (['positive', 'visions', 'what', 'they'], 'of'),
#  (['visions', 'of', 'they', 'believe'], 'what'),
#  (['of', 'what', 'believe', 'to'], 'they'),
#  (['what', 'they', 'to', 'be'], 'believe'),
#  (['they', 'believe', 'be', 'a'], 'to'),
#  (['believe', 'to', 'a', 'truly'], 'be'),
#  (['to', 'be', 'truly', 'free'], 'a'),
#  (['be', 'a', 'free', 'society'], 'truly'),
#  (['a', 'truly', 'society', 'however'], 'free'),
#  (['truly', 'free', 'however', 'ideas'], 'society'),
#  (['free', 'society', 'ideas', 'about'], 'however'),
#  (['society', 'however', 'about', 'how'], 'ideas')]

# %%
# save the training data, word to id mappings, id to word mappings, and corpus to pytorch tensors
import torch

# save the training data
torch.save(training_data, "../data/eve_training_data.pt")

# save the word to id mappings
torch.save(word_to_id, "../data/eve_word_to_id.pt")

# save the id to word mappings
torch.save(id_to_word, "../data/eve_id_to_word.pt")

# save the corpus
torch.save(corpus, "../data/eve_corpus.pt")
