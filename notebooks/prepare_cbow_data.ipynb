# %% [markdown]
# ### Create training data for CBOW:
# - For each word in your corpus, create a 5-item context window
# - The input will be the context words, and the target will be the center word
# - We'll need to convert these words into word IDs from your tokenizer
#
# ### Build the CBOW architecture:
# - Input layer (context words)
# - Hidden layer (embedding dimension)
# - Output layer (prediction of center word using softmax)

# %% [markdown]
# CREATE TRAINING DATA

# %%
import sys
sys.path.append('../scripts')

from tokenizer import tokenizer

# Load the wiki data
filename = "../data/wiki_text_data.txt"

text = open(filename, 'r', encoding='utf-8').read().lower()

# First tokenize the wiki text
word_to_id, id_to_word, corpus, unique_word_counts = tokenizer(text)
print("Tokenisation complete")
print(len(corpus))
# Out:
# Number of unique words included in word count before filtering:  253854
# Number of unique words included in word count after filtering:  71290
# Tokenisation complete
# 71290

# %%
# Generate the training data from the corpus
# The training data looks like a list of tuples, 
# where each tuple contains a list of context words and the target word (not the IDs)

def generate_training_data(corpus):
    data = []

    # start from index 2 and end 2 positions before the last word
    # this ensures we always have 2 words before and after the target word
    # for a 5-len sliding window

    for i in range(2, len(corpus) - 2):
        # Get the context words
        # 'i' is the index of the target word
        # [i-2:i] gets the two words before the target word
        # [i+1:i+3] gets the two words after the target word
        context_words = corpus[i-2:i] + corpus[i+1:i+3]
        
        # Get the target word
        target_word = corpus[i]

        # Append the tuple to the data list
        data.append((context_words, target_word))

    return data

# %%
# usage
training_data = generate_training_data(corpus)
print("CBOW training data generated")
# Out:
# CBOW training data generated

# %%
# check the function
training_data[:200]
# Out:
# [(['anarchism', 'originated', 'a', 'term'], 'as'),
#  (['originated', 'as', 'term', 'of'], 'a'),
#  (['as', 'a', 'of', 'abuse'], 'term'),
#  (['a', 'term', 'abuse', 'first'], 'of'),
#  (['term', 'of', 'first', 'used'], 'abuse'),
#  (['of', 'abuse', 'used', 'against'], 'first'),
#  (['abuse', 'first', 'against', 'early'], 'used'),
#  (['first', 'used', 'early', 'working'], 'against'),
#  (['used', 'against', 'working', 'class'], 'early'),
#  (['against', 'early', 'class', 'radicals'], 'working'),
#  (['early', 'working', 'radicals', 'including'], 'class'),
#  (['working', 'class', 'including', 'the'], 'radicals'),
#  (['class', 'radicals', 'the', 'diggers'], 'including'),
#  (['radicals', 'including', 'diggers', 'english'], 'the'),
#  (['including', 'the', 'english', 'revolution'], 'diggers'),
#  (['the', 'diggers', 'revolution', 'and'], 'english'),
#  (['diggers', 'english', 'and', 'sans'], 'revolution'),
#  (['english', 'revolution', 'sans', 'culottes'], 'and'),
#  (['revolution', 'and', 'culottes', 'french'], 'sans'),
#  (['and', 'sans', 'french', 'whilst'], 'culottes'),
#  (['sans', 'culottes', 'whilst', 'is'], 'french'),
#  (['culottes', 'french', 'is', 'still'], 'whilst'),
#  (['french', 'whilst', 'still', 'in'], 'is'),
#  (['whilst', 'is', 'in', 'pejorative'], 'still'),
#  (['is', 'still', 'pejorative', 'way'], 'in'),
#  (['still', 'in', 'way', 'to'], 'pejorative'),
#  (['in', 'pejorative', 'to', 'describe'], 'way'),
#  (['pejorative', 'way', 'describe', 'any'], 'to'),
#  (['way', 'to', 'any', 'act'], 'describe'),
#  (['to', 'describe', 'act', 'that'], 'any'),
#  (['describe', 'any', 'that', 'violent'], 'act'),
#  (['any', 'act', 'violent', 'means'], 'that'),
#  (['act', 'that', 'means', 'destroy'], 'violent'),
#  (['that', 'violent', 'destroy', 'organization'], 'means'),
#  (['violent', 'means', 'organization', 'society'], 'destroy'),
#  (['means', 'destroy', 'society', 'it'], 'organization'),
#  (['destroy', 'organization', 'it', 'has'], 'society'),
#  (['organization', 'society', 'has', 'also'], 'it'),
#  (['society', 'it', 'also', 'been'], 'has'),
#  (['it', 'has', 'been', 'taken'], 'also'),
#  (['has', 'also', 'taken', 'up'], 'been'),
#  (['also', 'been', 'up', 'positive'], 'taken'),
#  (['been', 'taken', 'positive', 'label'], 'up'),
#  (['taken', 'up', 'label', 'by'], 'positive'),
#  (['up', 'positive', 'by', 'self'], 'label'),
#  (['positive', 'label', 'self', 'defined'], 'by'),
#  (['label', 'by', 'defined', 'anarchists'], 'self'),
#  (['by', 'self', 'anarchists', 'word'], 'defined'),
#  (['self', 'defined', 'word', 'derived'], 'anarchists'),
#  (['defined', 'anarchists', 'derived', 'from'], 'word'),
#  (['anarchists', 'word', 'from', 'greek'], 'derived'),
#  (['word', 'derived', 'greek', 'without'], 'from'),
#  (['derived', 'from', 'without', 'archons'], 'greek'),
#  (['from', 'greek', 'archons', 'ruler'], 'without'),
#  (['greek', 'without', 'ruler', 'chief'], 'archons'),
#  (['without', 'archons', 'chief', 'king'], 'ruler'),
#  (['archons', 'ruler', 'king', 'political'], 'chief'),
#  (['ruler', 'chief', 'political', 'philosophy'], 'king'),
#  (['chief', 'king', 'philosophy', 'belief'], 'political'),
#  (['king', 'political', 'belief', 'rulers'], 'philosophy'),
#  (['political', 'philosophy', 'rulers', 'are'], 'belief'),
#  (['philosophy', 'belief', 'are', 'unnecessary'], 'rulers'),
#  (['belief', 'rulers', 'unnecessary', 'should'], 'are'),
#  (['rulers', 'are', 'should', 'be'], 'unnecessary'),
#  (['are', 'unnecessary', 'be', 'abolished'], 'should'),
#  (['unnecessary', 'should', 'abolished', 'although'], 'be'),
#  (['should', 'be', 'although', 'there'], 'abolished'),
#  (['be', 'abolished', 'there', 'differing'], 'although'),
#  (['abolished', 'although', 'differing', 'interpretations'], 'there'),
#  (['although', 'there', 'interpretations', 'what'], 'differing'),
#  (['there', 'differing', 'what', 'this'], 'interpretations'),
#  (['differing', 'interpretations', 'this', 'refers'], 'what'),
#  (['interpretations', 'what', 'refers', 'related'], 'this'),
#  (['what', 'this', 'related', 'social'], 'refers'),
#  (['this', 'refers', 'social', 'movements'], 'related'),
#  (['refers', 'related', 'movements', 'advocate'], 'social'),
#  (['related', 'social', 'advocate', 'elimination'], 'movements'),
#  (['social', 'movements', 'elimination', 'authoritarian'], 'advocate'),
#  (['movements', 'advocate', 'authoritarian', 'institutions'], 'elimination'),
#  (['advocate', 'elimination', 'institutions', 'particularly'],
#   'authoritarian'),
#  (['elimination', 'authoritarian', 'particularly', 'state'], 'institutions'),
#  (['authoritarian', 'institutions', 'state', 'anarchy'], 'particularly'),
#  (['institutions', 'particularly', 'anarchy', 'most'], 'state'),
#  (['particularly', 'state', 'most', 'use'], 'anarchy'),
#  (['state', 'anarchy', 'use', 'does'], 'most'),
#  (['anarchy', 'most', 'does', 'not'], 'use'),
#  (['most', 'use', 'not', 'imply'], 'does'),
#  (['use', 'does', 'imply', 'chaos'], 'not'),
#  (['does', 'not', 'chaos', 'nihilism'], 'imply'),
#  (['not', 'imply', 'nihilism', 'or'], 'chaos'),
#  (['imply', 'chaos', 'or', 'anomie'], 'nihilism'),
#  (['chaos', 'nihilism', 'anomie', 'but'], 'or'),
#  (['nihilism', 'or', 'but', 'rather'], 'anomie'),
#  (['or', 'anomie', 'rather', 'harmonious'], 'but'),
#  (['anomie', 'but', 'harmonious', 'anti'], 'rather'),
#  (['but', 'rather', 'anti', 'place'], 'harmonious'),
#  (['rather', 'harmonious', 'place', 'regarded'], 'anti'),
#  (['harmonious', 'anti', 'regarded', 'structures'], 'place'),
#  (['anti', 'place', 'structures', 'coercive'], 'regarded'),
#  (['place', 'regarded', 'coercive', 'economic'], 'structures'),
#  (['regarded', 'structures', 'economic', 'relations'], 'coercive'),
#  (['structures', 'coercive', 'relations', 'based'], 'economic'),
#  (['coercive', 'economic', 'based', 'upon'], 'relations'),
#  (['economic', 'relations', 'upon', 'voluntary'], 'based'),
#  (['relations', 'based', 'voluntary', 'association'], 'upon'),
#  (['based', 'upon', 'association', 'autonomous'], 'voluntary'),
#  (['upon', 'voluntary', 'autonomous', 'individuals'], 'association'),
#  (['voluntary', 'association', 'individuals', 'mutual'], 'autonomous'),
#  (['association', 'autonomous', 'mutual', 'aid'], 'individuals'),
#  (['autonomous', 'individuals', 'aid', 'governance'], 'mutual'),
#  (['individuals', 'mutual', 'governance', 'while'], 'aid'),
#  (['mutual', 'aid', 'while', 'easily'], 'governance'),
#  (['aid', 'governance', 'easily', 'offer'], 'while'),
#  (['governance', 'while', 'offer', 'visions'], 'easily'),
#  (['while', 'easily', 'visions', 'they'], 'offer'),
#  (['easily', 'offer', 'they', 'believe'], 'visions'),
#  (['offer', 'visions', 'believe', 'truly'], 'they'),
#  (['visions', 'they', 'truly', 'free'], 'believe'),
#  (['they', 'believe', 'free', 'however'], 'truly'),
#  (['believe', 'truly', 'however', 'ideas'], 'free'),
#  (['truly', 'free', 'ideas', 'about'], 'however'),
#  (['free', 'however', 'about', 'how'], 'ideas'),
#  (['however', 'ideas', 'how', 'an'], 'about'),
#  (['ideas', 'about', 'an', 'anarchist'], 'how'),
#  (['about', 'how', 'anarchist', 'might'], 'an'),
#  (['how', 'an', 'might', 'work'], 'anarchist'),
#  (['an', 'anarchist', 'work', 'vary'], 'might'),
#  (['anarchist', 'might', 'vary', 'considerably'], 'work'),
#  (['might', 'work', 'considerably', 'especially'], 'vary'),
#  (['work', 'vary', 'especially', 'with'], 'considerably'),
#  (['vary', 'considerably', 'with', 'respect'], 'especially'),
#  (['considerably', 'especially', 'respect', 'economics'], 'with'),
#  (['especially', 'with', 'economics', 'disagreement'], 'respect'),
#  (['with', 'respect', 'disagreement', 'brought'], 'economics'),
#  (['respect', 'economics', 'brought', 'origins'], 'disagreement'),
#  (['economics', 'disagreement', 'origins', 'predecessors'], 'brought'),
#  (['disagreement', 'brought', 'predecessors', 'kropotkin'], 'origins'),
#  (['brought', 'origins', 'kropotkin', 'others'], 'predecessors'),
#  (['origins', 'predecessors', 'others', 'argue'], 'kropotkin'),
#  (['predecessors', 'kropotkin', 'argue', 'before'], 'others'),
#  (['kropotkin', 'others', 'before', 'recorded'], 'argue'),
#  (['others', 'argue', 'recorded', 'history'], 'before'),
#  (['argue', 'before', 'history', 'human'], 'recorded'),
#  (['before', 'recorded', 'human', 'was'], 'history'),
#  (['recorded', 'history', 'was', 'organized'], 'human'),
#  (['history', 'human', 'organized', 'on'], 'was'),
#  (['human', 'was', 'on', 'principles'], 'organized'),
#  (['was', 'organized', 'principles', 'anthropologists'], 'on'),
#  (['organized', 'on', 'anthropologists', 'follow'], 'principles'),
#  (['on', 'principles', 'follow', 'engels'], 'anthropologists'),
#  (['principles', 'anthropologists', 'engels', 'believing'], 'follow'),
#  (['anthropologists', 'follow', 'believing', 'hunter'], 'engels'),
#  (['follow', 'engels', 'hunter', 'gatherer'], 'believing'),
#  (['engels', 'believing', 'gatherer', 'bands'], 'hunter'),
#  (['believing', 'hunter', 'bands', 'were'], 'gatherer'),
#  (['hunter', 'gatherer', 'were', 'egalitarian'], 'bands'),
#  (['gatherer', 'bands', 'egalitarian', 'lacked'], 'were'),
#  (['bands', 'were', 'lacked', 'division'], 'egalitarian'),
#  (['were', 'egalitarian', 'division', 'labour'], 'lacked'),
#  (['egalitarian', 'lacked', 'labour', 'accumulated'], 'division'),
#  (['lacked', 'division', 'accumulated', 'wealth'], 'labour'),
#  (['division', 'labour', 'wealth', 'decreed'], 'accumulated'),
#  (['labour', 'accumulated', 'decreed', 'law'], 'wealth'),
#  (['accumulated', 'wealth', 'law', 'had'], 'decreed'),
#  (['wealth', 'decreed', 'had', 'equal'], 'law'),
#  (['decreed', 'law', 'equal', 'access'], 'had'),
#  (['law', 'had', 'access', 'resources'], 'equal'),
#  (['had', 'equal', 'resources', 'william'], 'access'),
#  (['equal', 'access', 'william', 'godwin'], 'resources'),
#  (['access', 'resources', 'godwin', 'organisation'], 'william'),
#  (['resources', 'william', 'organisation', 'rothbard'], 'godwin'),
#  (['william', 'godwin', 'rothbard', 'find'], 'organisation'),
#  (['godwin', 'organisation', 'find', 'attitudes'], 'rothbard'),
#  (['organisation', 'rothbard', 'attitudes', 'taoism'], 'find'),
#  (['rothbard', 'find', 'taoism', 'ancient'], 'attitudes'),
#  (['find', 'attitudes', 'ancient', 'china'], 'taoism'),
#  (['attitudes', 'taoism', 'china', 'found'], 'ancient'),
#  (['taoism', 'ancient', 'found', 'similar'], 'china'),
#  (['ancient', 'china', 'similar', 'stoic'], 'found'),
#  (['china', 'found', 'stoic', 'zeno'], 'similar'),
#  (['found', 'similar', 'zeno', 'citium'], 'stoic'),
#  (['similar', 'stoic', 'citium', 'according'], 'zeno'),
#  (['stoic', 'zeno', 'according', 'repudiated'], 'citium'),
#  (['zeno', 'citium', 'repudiated', 'omnipotence'], 'according'),
#  (['citium', 'according', 'omnipotence', 'its'], 'repudiated'),
#  (['according', 'repudiated', 'its', 'intervention'], 'omnipotence'),
#  (['repudiated', 'omnipotence', 'intervention', 'regimentation'], 'its'),
#  (['omnipotence', 'its', 'regimentation', 'proclaimed'], 'intervention'),
#  (['its', 'intervention', 'proclaimed', 'sovereignty'], 'regimentation'),
#  (['intervention', 'regimentation', 'sovereignty', 'moral'], 'proclaimed'),
#  (['regimentation', 'proclaimed', 'moral', 'individual'], 'sovereignty'),
#  (['proclaimed', 'sovereignty', 'individual', 'anabaptists'], 'moral'),
#  (['sovereignty', 'moral', 'anabaptists', 'one'], 'individual'),
#  (['moral', 'individual', 'one', 'six'], 'anabaptists'),
#  (['individual', 'anabaptists', 'six', 'th'], 'one'),
#  (['anabaptists', 'one', 'th', 'century'], 'six'),
#  (['one', 'six', 'century', 'europe'], 'th'),
#  (['six', 'th', 'europe', 'sometimes'], 'century'),
#  (['th', 'century', 'sometimes', 'considered'], 'europe'),
#  (['century', 'europe', 'considered', 'religious'], 'sometimes')]

# %%
# save the training data, word to id mappings, id to word mappings, and corpus to pytorch tensors
import torch

# save the training data
torch.save(training_data, "../data/eve_training_data.pt")

# save the word to id mappings
torch.save(word_to_id, "../data/eve_word_to_id.pt")

# save the id to word mappings
torch.save(id_to_word, "../data/eve_id_to_word.pt")

# save the corpus
torch.save(corpus, "../data/eve_corpus.pt")
