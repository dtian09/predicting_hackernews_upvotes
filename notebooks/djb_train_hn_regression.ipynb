# %%
import pandas as pd
import torch

# %%
file_path = "../data/hn_sample_1percent.parquet"
df = pd.read_parquet(file_path)

# print the first 5 rows of the dataframe
display(df.head())
df.describe()
# Out:
#         id                                   title  \
# 0  4600001                      The iPhone of 2022
# 1  1300001          IPad users targeted by hackers
# 2  3450001                  A brief history of C++
# 3   750019  Chrome for Mac: more usable than ever.
# 4   750026           Scaling up a Quantum Computer
#
#                                                  url  score  \
# 0  http://www.theatlantic.com/technology/archive/...      2
# 1  http://www.telegraph.co.uk/technology/apple/76...      1
# 2  http://www.hitmill.com/programming/cpp/cppHist...      1
# 3  http://thenextweb.com/2009/08/08/chrome-mac-us...     21
# 4   http://www.technologyreview.com/computing/23137/     12
#
#                  time user_posted  user_karma
# 0 2012-10-02 01:02:31    bmahmood        2226
# 1 2010-04-27 23:30:15  McKittrick        2326
# 2 2012-01-11 01:14:29       eraad          67
# 3 2009-08-09 00:44:00     mgcreed        1419
# 4 2009-08-09 00:51:17    jacquesm      227883
#                  id         score                           time  \
# count  5.107800e+04  51078.000000                          51078
# mean   1.762114e+07     13.571205  2017-08-20 22:31:30.300109568
# min    6.820000e+02      0.000000            2007-02-23 14:52:13
# 25%    6.940389e+06      1.000000            2013-12-20 07:32:29
# 50%    1.587232e+07      2.000000     2017-12-07 17:59:19.500000
# 75%    2.705794e+07      3.000000  2021-05-06 02:00:52.750000128
# max    4.183130e+07   1697.000000            2024-10-13 21:29:16
# std    1.215289e+07     57.217135                            NaN
#
#           user_karma
# count   51078.000000
# mean    13120.737088
# min      -247.000000
# 25%        27.000000
# 50%       974.500000
# 75%      7753.750000
# max    394659.000000
# std     31465.886502
